# %% [markdown]
# <a href="https://colab.research.google.com/github/nadya-az/digital_image_processing/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%962.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('/content/фото1.jpeg')
processed_image = cv2.medianBlur(image, 3)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('/content/1.jpeg')
processed_image = cv2.medianBlur(image, 3)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/187947-night_shoot02_original.jpeg')
processed_image = cv2.medianBlur(image, 3)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/_1.webp')
processed_image = cv2.medianBlur(image, 3)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/2014_Ziarno_na_fotografii_analogowej.jpeg')
processed_image = cv2.medianBlur(image, 3)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
import cv2
import numpy as np
import argparse

image = cv2.imread('/content/фото1.jpeg')

kernel = np.ones((3,3),np.float32)/9
processed_image = cv2.filter2D(image,-1,kernel)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/1.jpeg')

kernel = np.ones((3,3),np.float32)/9
processed_image = cv2.filter2D(image,-1,kernel)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/2014_Ziarno_na_fotografii_analogowej.jpeg')

kernel = np.ones((3,3),np.float32)/9
processed_image = cv2.filter2D(image,-1,kernel)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/_1.webp')

kernel = np.ones((3,3),np.float32)/9
processed_image = cv2.filter2D(image,-1,kernel)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
image = cv2.imread('/content/187947-night_shoot02_original.jpeg')

kernel = np.ones((3,3),np.float32)/9
processed_image = cv2.filter2D(image,-1,kernel)

cv2.imwrite('processed_image.png', processed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')

# %%
import numpy as np
import argparse
import imutils
import cv2

image = cv2.imread("/content/IMAGE (1).jpg") 
fragment = cv2.imread("/content/Panda.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_6.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_7.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_1.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_2.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_3.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_4.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_5.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_8.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_9.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/IMAGE.jpg") 
fragment = cv2.imread("/content/Et_10.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("/content/Image (2).jpg") 
fragment = cv2.imread("/content/cmi_b0726956.png") 
(fragmentHeight, fragmentWidth) = fragment.shape[:2]

result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)

topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]

mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)

image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
